# %% [markdown]
# # Instrument: `OpticalSpectrumAnalyzer`

# %%
# %load_ext autoreload
# %autoreload 2
from start import start

osa = start('Apex Optical Spectrum Analyzer')
# Out:
# It is alive
# Apex AP2440A
# Here is what to test:
# startup
# spectrum
# wlRange

# %%
# osa.spectrum(avgCnt=1).simplePlot(livePlot=True, label='Original view')
# oldWlRange = osa.wlRange
# osa.wlRange = [1543, 1555]
sp1 = osa.spectrum()#.simplePlot(livePlot=True, label='Zoom view')
# osa.wlRange = oldWlRange

# %%
sp1.simplePlot('b', lw=3, label='Drop port (a.k.a. R port)')
sp2.simplePlot('r', lw=3, label='Thru port (a.k.a. T port)')
import matplotlib.pyplot as plt
plt.title('FBG spectra w/ 1548.52nm +- 0.5nm')
# Out:
# Text(0.5,1,'FBG spectra w/ 1548.52nm +- 0.5nm')
