# %%
# %load_ext autoreload
# %autoreload 2
from start import start

pna = start('PNA5222A')

# %%
# Setup a S21 measurement
pna.measurementSetup(measType='S21')
pna.sweepSetup(startFreq=10e6, stopFreq=1e9, nPts=1000)
pna.sweepEnable(True)
spct = pna.spectrum()
spct.simplePlot()
pna.run() # put it back to live
